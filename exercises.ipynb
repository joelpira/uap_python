# %% [markdown]
# # Direction
# You may search the internet for the Python functions but do not ask AI to do it from you.
#
# ## 1. Pig Latin
#
# The rules for translating words from English into Pig Latin
#
# - If the word begins with a vowel (a, e, i, o, or u), add “way” to the end of the
# word. So “air” becomes “airway” and “eat” becomes “eatway.”
#
# - If the word begins with any other letter, take the first letter, put it at the end of
# the word, and then add “ay.” Thus, “python” becomes “ythonpay” and “computer” becomes “omputercay.”
#
#
# For this exercise, write a Python function (pig_latin) that takes a string as input, assumed to be an English word. The function should return the translation of this
# word into Pig Latin. You may assume that the word contains no capital letters or
# punctuation.
#
#
# ## 2. Average
#
# Ask a number from a user to get the average, and the sum.
#
# ## 3. Number Guessing Game
#
# Guess a number from 1-20.
#
# ## 4. Sort Words from Input
#
# User enters words to sort. No limit on the number of words. If a phrase is entered, break it.
#
#
#
# https://www.dataquest.io/blog/python-practice-exercises/

# %% [markdown]
# # <span style='color: blue'>Set 2: Intermediate Python Exercises</span>
#
# These exercises are based on lessons 12–16. Write the code yourself, test normal and invalid inputs, and add short comments where your reasoning may not be obvious.
#
# ## 5. Validated Student Property
#
# Create a `Student` class with these properties:
#
# - `name`: must be a non-empty string.
# - `age`: must be an integer from 1 to 120.
# - `grade`: must be a number from 0 to 100.
#
# Store the values internally with underscore-prefixed attributes such as `_name`. Use `@property` and setter methods to validate assignments.
#
# Test your class by:
#
# - Creating a valid student.
# - Updating each property with valid values.
# - Trying an empty name, a negative age, and a grade above 100.
# - Displaying the student's information.
#
# ## 6. Read-Only Calculated Property
#
# Create a `Rectangle` class with `width` and `height` properties. Both dimensions must be positive numbers.
#
# Add read-only properties for:
#
# - `area`
# - `perimeter`
# - `is_square`
#
# Attempt to assign a value to `area` and confirm that Python raises an `AttributeError`.
#
# ## 7. Bank Account Exceptions
#
# Create a `BankAccount` class with:
#
# - `deposit(amount)`
# - `withdraw(amount)`
# - A validated `balance` property
#
# Create these custom exceptions:
#
# - `InvalidAmountError`
# - `InsufficientFundsError`
#
# Raise the correct exception when:
#
# - An amount is zero or negative.
# - A withdrawal is greater than the current balance.
# - A non-numeric amount is supplied.
#
# Write a short test program that catches each exception separately and prints a useful message.
#
# ## 8. Safe File Statistics
#
# Write a function named `file_statistics(path)` that reads a text file and returns a dictionary containing:
#
# - Number of lines.
# - Number of words.
# - Number of non-whitespace characters.
# - The longest line.
#
# Requirements:
#
# - Use `pathlib.Path` or a `with open(...)` context manager.
# - Raise a clear `FileNotFoundError` if the path does not exist.
# - Handle an empty file.
# - Write a small sample file to test the function.
#
# ## 9. JSON Contact Book
#
# Create a contact book stored in a JSON file. Each contact should contain a name, phone number, and email address.
#
# Implement functions to:
#
# - Load contacts from the JSON file.
# - Add a contact.
# - Search by name.
# - Delete a contact.
# - Save the updated contacts.
#
# Handle these cases cleanly:
#
# - The file does not exist.
# - The JSON is invalid.
# - A contact already exists.
# - A requested contact cannot be found.
#
# ## 10. Build a Small Module and Package
#
# Create this project structure:
#
# ```text
# study_tools/
#     __init__.py
#     number_tools.py
#     text_tools.py
# main.py
# ```
#
# Implement:
#
# - `number_tools.is_prime(number)`
# - `number_tools.factorial(number)`
# - `text_tools.count_vowels(text)`
# - `text_tools.reverse_words(text)`
#
# Import the functions into `main.py` using explicit imports. Add an `if __name__ == "__main__":` block that demonstrates each function.
#
# ## 11. Import Inspection
#
# Write a program that imports `math`, `json`, and `pathlib`, then prints useful module attributes:
#
# - `__name__`
# - `__doc__`
# - `__file__` when available
#
# Use `getattr()` so the program does not fail when an attribute is missing. Explain in a comment what each attribute means.
#
# ## 12. Iterable and Iterator Practice
#
# Create a class called `Countdown` that accepts a starting number and can be used in a `for` loop.
#
# Requirements:
#
# - Implement `__iter__()`.
# - Implement `__next__()`.
# - Yield values from the starting number down to 0.
# - Raise `StopIteration` after 0.
# - Verify that the iterator is consumed after one complete loop.
#
# Then compare your class with `iter()` and `next()` on a normal list.
#
# ## 13. Generator Pipeline
#
# Write three generator functions:
#
# 1. `read_numbers(values)` yields only numeric values.
# 2. `square_numbers(values)` yields the square of each value.
# 3. `format_numbers(values)` yields strings such as `"Value: 25"`.
#
# Connect them into a lazy pipeline and print the final values. Confirm that the functions produce values only as the pipeline is consumed.
#
# ## 14. Generator-Based File Reader
#
# Write a generator called `non_empty_lines(path)` that reads a text file one line at a time and yields only non-empty, stripped lines.
#
# Use it to:
#
# - Count non-empty lines.
# - Print the first three non-empty lines.
# - Process a file without using `readlines()`.
#
# ## 15. Generator with `send()`
#
# Create a generator called `running_total()` that starts at zero and accepts numbers sent into it with `.send(value)`.
#
# For each value received, yield the updated total. Demonstrate:
#
# - Starting the generator with `next()`.
# - Sending at least three numbers.
# - Closing the generator with `.close()`.
#
# ## 16. List, Set, Tuple, and Dictionary Analysis
#
# Write a function named `analyze_values(values)` that returns a dictionary containing:
#
# - The original values as a list.
# - The unique values as a set.
# - The values sorted in a tuple.
# - A frequency dictionary counting each value.
# - The smallest and largest values.
#
# Test it with duplicate numbers and explain why each collection type is useful in the result.
#
# ## 17. Word Frequency Analyzer
#
# Ask the user for a paragraph and analyze it using `collections.Counter`.
#
# Your program should:
#
# - Convert text to lowercase.
# - Remove common punctuation.
# - Count each word.
# - Display the five most common words.
# - Display the total number of unique words.
#
# Do not use a third-party package.
#
# ## 18. Queue Simulator with `deque`
#
# Use `collections.deque` to build a small customer-service queue.
#
# Implement commands to:
#
# - Add a customer to the back.
# - Serve the customer at the front.
# - Add an urgent customer to the front.
# - Display the current queue.
# - Stop the program.
#
# Handle attempts to serve from an empty queue without crashing.
#
# ## 19. Collection Transformation Challenge
#
# Given:
#
# ```python
# records = [
#     ("Ana", "Python", 88),
#     ("Ben", "Python", 72),
#     ("Ana", "SQL", 91),
#     ("Cara", "Python", 95),
# ]
# ```
#
# Use comprehensions and built-in functions to produce:
#
# - A set of student names.
# - A dictionary mapping each student to their average score.
# - A list of students whose average is at least 85.
# - A dictionary mapping each course to its highest score.
# - A sorted list of records by score from highest to lowest.
#
# ## 20. Capstone: Lazy Course Report
#
# Build a small course-report program that combines the previous topics.
#
# Requirements:
#
# 1. Create a `Course` class with validated `name` and `capacity` properties.
# 2. Store enrolled students in a list or dictionary.
# 3. Raise custom exceptions for duplicate enrollment and a full course.
# 4. Load student records from a JSON file.
# 5. Use a generator to yield students one at a time.
# 6. Use `Counter` to summarize the students' chosen topics.
# 7. Provide read-only properties for enrollment count and available seats.
# 8. Place reusable code in a module and run the demonstration from `main.py`.
# 9. Add tests for successful enrollment, duplicate enrollment, invalid capacity, and a full course.
#
# ### Suggested completion checklist
#
# - [ ] Exercises 5–7: properties, validation, and custom exceptions.
# - [ ] Exercises 8–11: files, JSON, modules, and imports.
# - [ ] Exercises 12–15: iterators, generators, and coroutines.
# - [ ] Exercises 16–19: lists, tuples, sets, dictionaries, and `collections`.
# - [ ] Exercise 20: integrated capstone project.
